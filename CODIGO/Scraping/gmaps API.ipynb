# %% [markdown]
# ## gmaps api

# %%
#install googlemaps pip install -U googlemaps
import googlemaps as gm
import pandas as pd

#for sampling
import random

# %% [markdown]
# ### Base de datos

# %%
#parametrizar ruta
PATH = 'F:\hackaton\Hackaton-BBVA-2022-Conjunto-de-Cantor\DATOS\DB\\'
df = pd.read_csv(PATH+'Final_Data_Hackathon_2022.csv')

# %% [markdown]
# ### API

# %%
gmaps = gm.Client(key='AIzaSyDutpd8aWodj-mQ-qUvBrapIWp5KzcC8D4')

# %% [markdown]
# #### Función

# %%
def places(busqueda):
    places_result_x = gmaps.places(busqueda)
    try:
        place_id_x = places_result_x['results'][0]['place_id']
        place_x = gmaps.place(place_id = place_id_x)
    except IndexError:
        place_x = []
    return places_result_x, place_x

# %% [markdown]
# ### Muestra

# %%
samples = random.sample(range(len(df.index)),50)
samples
muestra = df.iloc[samples]

# %%
muestra
# Out:
#                     Nombre1               Nombre2        Nombre3  \
# 482      FERTRUK S SA DE CV                   NaN            NaN
# 22955  HIDROCARBUROS GUADAL          UPE SA DE CV            NaN
# 4255     ACEROPCIS SA DE CV                   NaN            NaN
# 20394     INTECSYS,SA DE CV                   NaN            NaN
# 12779  PRODUCTOS JAMEX SA D                  E CV            NaN
# 4401   COMERCIAL ANTIGUA  S               A DE CV            NaN
# 5732   RECONSTRUCTORA ALPHA             #SA DE CV            NaN
# 10572  BROCAS ABRASIVOS Y R  EPRESENTACIONES SA D           E CV
# 13950   TINA CONSTRUCCIONES              SA DE CV            NaN
# 28253  RIOS INGENIERIA OBRA   S Y SERVICIOS SA DE             CV
# 20645  PSI PINTURAS DEL CEN          TRO SA DE CV            NaN
# 6619   DISENO FORMAS COMPUT        ACION#SA DE CV            NaN
# 20510  ORGANIZACION EMPRESA  RIAL DEL BAJIO SA DE             CV
# ...

# %% [markdown]
# ### frases de busqueda

# %%
busquedas = []
for name in range(len(muestra.index)):
    #busqueda = muestra.iloc[name]['NombComp']+', '+muestra.iloc[name]['Direccion1']+', '+muestra.iloc[name]['Colonia']+', '+muestra.iloc[name]['MunicipioDel']
    busqueda = muestra.iloc[name]['NombComp']+', '+muestra.iloc[name]['CP'].astype(str)+', '+muestra.iloc[name]['MunicipioDel']+', '+muestra.iloc[name]['Estado']
    busquedas.append(busqueda)

# %%
busquedas
#Centro 220, Ampliación Misiones, 53140 Naucalpan de Juárez, Méx.
# Out:
# ['FERTRUK S  SA DE CV, 2750, AZCAPOTZALCO, CDMX',
#  'HIDROCARBUROS GUADALUPE  SA DE CV, 72980, AMOZOC, Puebla',
#  'ACEROPCIS  SA DE CV, 52783, HUIXQUILUCAN, Estado de Mexico',
#  'INTECSYS, SA DE CV, 7360, GUSTAVO A MADERO, CDMX',
#  'PRODUCTOS JAMEX  SA DE CV, 45235, ZAPOPAN, Jalisco',
#  'COMERCIAL ANTIGUA  SA DE CV, 91517, COATEPEC, Veracruz',
#  'RECONSTRUCTORA ALPHA SA DE CV, 31105, CHIHUAHUA, Chihuahua',
#  'BROCAS ABRASIVOS Y REPRESENTACIONES  SA DE CV, 94500, CORDOBA, Veracruz',
#  'TINA CONSTRUCCIONES  SA DE CV, 1600, ALVARO OBREGON, CDMX',
#  'RIOS INGENIERIA OBRAS Y SERVICIOS  SA DE CV, 4320, COYOACAN, CDMX',
#  'PSI PINTURAS DEL CENTRO  SA DE CV, 72580, PUEBLA, Puebla',
#  'DISENO FORMAS COMPUTACION SA DE CV, 15900, VENUSTIANO CARRANZA, CDMX',
#  'ORGANIZACION EMPRESARIAL DEL BAJIO SA DE CV, 37330, LEON, Guanajuato',
#  'INGENIERIA ELECTRICAY EQUIPAMENTO EN CL IMAS  SA DE CV, 27000, TORREON, Coahuila',
# ...

# %% [markdown]
# ####  Consumo

# %%
results_2 = {Nombre:[] for Nombre in muestra['NombComp']}

for name in range(len(muestra.index)):
    busqueda = busquedas[name]
    results_2[muestra.iloc[name]['NombComp']] = list(places(busqueda))
    
    #print(busquedas[name])

# %% [markdown]
# ### Informacion contextual

# %%
results_2['BROCAS ABRASIVOS Y REPRESENTACIONES  SA DE CV'][0]['results'][0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'formatted_address': 'Av. 3, Centro, 94500 Córdoba, Ver., Mexico',
#  'geometry': {'location': {'lat': 18.8882215, 'lng': -96.92882039999999},
#   'viewport': {'northeast': {'lat': 18.88959152989272,
#     'lng': -96.92745092010728},
#    'southwest': {'lat': 18.88689187010728, 'lng': -96.93015057989273}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#  'icon_background_color': '#4B96F3',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#  'name': 'Brocas, Abrasivos y Representaciones S.A. de C.V.',
#  'opening_hours': {'open_now': False},
#  'place_id': 'ChIJfVWnX1zlxIURCCDumchfdB4',
#  'plus_code': {'compound_code': 'V3QC+7F Córdoba, Veracruz',
#   'global_code': '76C5V3QC+7F'},
#  'rating': 4.3,
#  'reference': 'ChIJfVWnX1zlxIURCCDumchfdB4',
#  'types': ['hardware_store', 'store', 'point_of_interest', 'establishment'],
#  'user_ratings_total': 19}

# %%
#info general
tipo_negocio = results_2['BROCAS ABRASIVOS Y REPRESENTACIONES  SA DE CV'][0]['results'][0]['types']

# %%
results_2['BROCAS ABRASIVOS Y REPRESENTACIONES  SA DE CV'][1]['result']
# Out:
# {'address_components': [{'long_name': 'Avenida 3',
#    'short_name': 'Av. 3',
#    'types': ['route']},
#   {'long_name': 'Centro',
#    'short_name': 'Centro',
#    'types': ['sublocality_level_1', 'sublocality', 'political']},
#   {'long_name': 'Córdoba',
#    'short_name': 'Córdoba',
#    'types': ['locality', 'political']},
#   {'long_name': 'Veracruz',
#    'short_name': 'Ver.',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Mexico',
#    'short_name': 'MX',
#    'types': ['country', 'political']},
#   {'long_name': '94500', 'short_name': '94500', 'types': ['postal_code']}],
#  'adr_address': '<span class="street-address">Av. 3</span>, <span class="extended-address">Centro</span>, <span class="postal-code">94500</span> <span class="locality">Córdoba</span>, <span class="region">Ver.</span>, <span class="country-name">Mexico</span>',
#  'business_status': 'OPERATIONAL',
#  'current_opening_hours': {'open_now': False,
# ...

# %%
for r in results_2['BROCAS ABRASIVOS Y REPRESENTACIONES  SA DE CV'][1]['result1']:
    print(r['type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [75], line 1
# ----> 1 for r in results_2['BROCAS ABRASIVOS Y REPRESENTACIONES  SA DE CV'][1]['result1']:
#       2     print(r['type'])
#
# KeyError: 'result1'

# %% [markdown]
# #### validacion de resultados

# %%
for i in results_2.keys():
    print(results_2[i],results_2[i][1],'\n','---------------')

# %%
results_2[k][1]['result']['address_components'][6]['long_name']

# %% [markdown]
# ### Salida:
# #### general
# name
# dirección
# rating
# #### individual
# reviews
# horario
# lat,long
# website
# relative_time_description
# rating

# %%
name = caso1[1]['result']['name']

# %%
address = caso1[0]['results'][0]['formatted_address']

# %%
rating = caso1[0]['results'][0]['rating']

# %%
#solo si existen
reviews = caso1[1]['result']['reviews']
review_time = caso1[1]['result']['reviews'][0]['relative_time_description']

# %%
opening_hours = r2['result']['current_opening_hours']['weekday_text']

# %%
if caso1[0]['status'] == 'OK':
    salida = {'name':name, 'addres':address,'rating':rating}
    if 'reviews' in caso1[1].keys():
        salida['reviews'] = caso1[1]['result']['reviews']
        salida['review_time'] = caso1[1]['result']['reviews'][0]['relative_time_description']
        if 'current_opening_hours' in caso1[1]['result'].keys():
            salida['hours'] = caso1[1]['result']['current_opening_hours']['weekday_text']
salida
# Out:
# {'name': 'Lavado Inteligente',
#  'addres': 'Centro 220, Ampliación Misiones, 53140 Naucalpan de Juárez, Méx., Mexico',
#  'rating': 5}

# %%
r2['result']['reviews'][0]['relative_time_description']
# Out:
# '10 months ago'

# %%
caso1[0]['status']
# Out:
# 'OK'

# %%
zona = places('begocios en san simon tolanuhac')

# %%
zona[0]['results']
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '5 de Febrero 1351, San Simón, Benito Juárez, 03660 Ciudad de México, CDMX, Mexico',
#   'geometry': {'location': {'lat': 19.3733244, 'lng': -99.14311250000002},
#    'viewport': {'northeast': {'lat': 19.37466102989272,
#      'lng': -99.14166507010728},
#     'southwest': {'lat': 19.37196137010728, 'lng': -99.14436472989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Cremeria y abarrotes san simon',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113129502774174792471">A Google User</a>'],
# ...
