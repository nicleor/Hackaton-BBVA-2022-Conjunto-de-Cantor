# %% [markdown]
# ## gmaps api

# %%
#install googlemaps pip install -U googlemaps
import googlemaps as gm
import pandas as pd

#for sampling
import random

# %% [markdown]
# ### Base de datos

# %%
#parametrizar ruta
PATH = 'F:\hackaton\Hackaton-BBVA-2022-Conjunto-de-Cantor\DATOS\DB\\'
df = pd.read_csv(PATH+'Final_Data_Hackathon_2022.csv')

# %% [markdown]
# ### API

# %%
gmaps = gm.Client(key='AIzaSyDutpd8aWodj-mQ-qUvBrapIWp5KzcC8D4')

# %% [markdown]
# #### Función

# %%
def places(busqueda):
    places_result_x = gmaps.places(busqueda)
    try:
        place_id_x = places_result_x['results'][0]['place_id']
        place_x = gmaps.place(place_id = place_id_x)
    except IndexError:
        place_x = []
    return places_result_x, place_x

# %% [markdown]
# ### Muestra

# %%
#samples = random.sample(range(len(df.index)),50)
samples
muestra = df.iloc[samples]

# %%
muestra
# Out:
#                     Nombre1               Nombre2            Nombre3  \
# 7310     LAVADO INTELIGENTE              SA DE CV                NaN
# 28559   GASOLINERA IGLUF SA                 DE CV                NaN
# 8183   PRESTADORA INT DE SE  RV PARA LA IND DE OC   CIDENTE SA DE CV
# 31484  DRAGADOS DEL GOLFO S               A DE CV                NaN
# 827     GRUPO INTRELURVI SA                 DE CV                NaN
# 7107   CONSTRUCCION MATERIA  LES Y CONCRETOS DE M  ICHOACAN SA DE CV
# 2546   SINERGIA Y MASIVOS S               A DE CV                NaN
# 26701  COMPU GADGET DE MEXI      CO S DE RL DE CV                NaN
# 14716  MAKIPARTES DEL SURES       TE S#AA DE C#V#                NaN
# 13956  PINTURAS CON IMAGINA         CION SA DE CV                NaN
# 22626  SURCONSA DE MEXICO S               A DE CV                NaN
# 24012  LE PARFUM ACCESORIOS   Y PERFUMES SA DE CV                NaN
# 31839  ABASTECEDORA DE SEMI  LLAS DE OAXACA SA DE                 CV
# ...

# %% [markdown]
# ### frases de busqueda

# %%
busquedas = []
for name in range(len(muestra.index)):
    #busqueda = muestra.iloc[name]['NombComp']+', '+muestra.iloc[name]['Direccion1']+', '+muestra.iloc[name]['Colonia']+', '+muestra.iloc[name]['MunicipioDel']
    busqueda = muestra.iloc[name]['NombComp']+', '+muestra.iloc[name]['CP'].astype(str)+', '+muestra.iloc[name]['MunicipioDel']
    busquedas.append(busqueda)

# %%
busquedas
#Centro 220, Ampliación Misiones, 53140 Naucalpan de Juárez, Méx.
# Out:
# ['LAVADO INTELIGENTE  SA DE CV, 53140, NAUCALPAN',
#  'GASOLINERA IGLUF  SA DE CV, 35760, RODEO',
#  'PRESTADORA INT DE SERV PARA LA IND DE OCCIDENTE  SA DE CV, 45070, ZAPOPAN',
#  'DRAGADOS DEL GOLFO  SA DE CV, 96400, COATZACOALCOS',
#  'GRUPO INTRELURVI  SA DE CV, 8200, IZTACALCO',
#  'CONSTRUCCION MATERIALES Y CONCRETOS DE MICHOACAN  SA DE CV, 58000, MORELIA',
#  'SINERGIA Y MASIVOS  SA DE CV, 31000, CHIHUAHUA',
#  'COMPU GADGET DE MEXICO S DE RL DE CV, 54913, TULTITLAN',
#  'MAKIPARTES DEL SURESTE SA DE CV, 71238, SAN AGUSTIN DE LAS JUNTAS',
#  'PINTURAS CON IMAGINACION  SA DE CV, 14100, TLALPAN',
#  'SURCONSA DE MEXICO  SA DE CV, 50240, TOLUCA',
#  'LE PARFUM ACCESORIOSY PERFUMES  SA DE CV, 31000, CHIHUAHUA',
#  'ABASTECEDORA DE SEMILLAS DE OAXACA SA DE CV, 68000, OAXACA DE JUAREZ',
#  'EMPAQUES UNIVERSALESPARA ALIMENTOS  SA DE CV, 45640, TLAJOMULCO DE ZU#IGA',
#  'LMA PROYECTOS SA DE CV, 64346, MONTERREY',
#  'CRIBIO  SA DE CV, 80160, CULIACAN',
# ...

# %% [markdown]
# ####  Consumo

# %%
#caso: 'LAVADO INTELIGENTE  SA DE CV, COLINA DE LA PAZ 25S DEL MONTE, BOULEVARES, NAUCALPAN'
caso1 = list(places('LAVADO INTELIGENTE  SA DE CV, 53140, NAUCALPAN'))

# %%
#for i in range(len(caso1[0]['results'])):
lista = [(caso1[0]['results'][i]['name'],caso1[0]['results'][i]['formatted_address']) for i in range(len(caso1[0]['results']))]

# %%
results_2 = {Nombre:[] for Nombre in muestra['NombComp']}

for name in range(len(muestra.index)):
    busqueda = busquedas[name]
    results_2[muestra.iloc[name]['NombComp']] = list(places(busqueda))
    
    #print(busquedas[name])

# %%
for i in range(len(results_2['LAVADO INTELIGENTE  SA DE CV'][0]['results'])):
    print(results_2['LAVADO INTELIGENTE  SA DE CV'][0]['results'][i]['name'])
# Out:
# Lavado Inteligente
# Lavado Inteligente

# %% [markdown]
# #### validacion de resultados

# %%
for i in results_2.keys():
    print(results_2[i],results_2[i][1],'\n','---------------')

# %% [markdown]
# ####  CP

# %%
results_2['LAVADO INTELIGENTE  SA DE CV'][0]['results'][0]['formatted_address']
# Out:
# 'Centro 220, Ampliación Misiones, 53140 Naucalpan de Juárez, Méx., Mexico'

# %%
results_2['SISTEMAS DE AUTOMATIZACION Y CONTROL DELCENTRO  SA DE CV'][1]['result']['address_components'][6]['long_name']
# Out:
# '02080'

# %%
results_2[k][1]['result']['address_components'][6]['long_name']

# %%
cps = [ k for k in results_2.keys() if results_2[k][1] == []]

# %%
no_vacios = list(results_2.keys())

# %%
for k in cps:
    no_vacios.remove(k)

# %%
for ele in no_vacios:
    try:
        print(results_2[ele][1]['result']['address_components'][6]['long_name'])
    except:
        r = [d for d in results_2[ele][1]['result']['address_components'] if d['type'] == 'postal_code']
        print(r)
# Out:
# 53140
# 96400
# 08100
# 58130
# 31000
# 08500
# Mexico
# 14100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [288], line 3
#       2 try:
# ----> 3     print(results_2[ele][1]['result']['address_components'][6]['long_name'])
#       4 except:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [288], line 5
#       3     print(results_2[ele][1]['result']['address_components'][6]['long_name'])
#       4 except:
# ----> 5     r = [d for d in results_2[ele][1]['result']['address_components'] if d['type'] == 'postal_code']
#       6     print(r)
#
# Cell In [288], line 5, in <listcomp>(.0)
#       3     print(results_2[ele][1]['result']['address_components'][6]['long_name'])
#       4 except:
# ...

# %%
 print(results_2[ele][1]['result']['address_components'])
# Out:
# [{'long_name': 'Toluca de Lerdo', 'short_name': 'Toluca de Lerdo', 'types': ['locality', 'political']}, {'long_name': 'Delegación Santa María Totoltepec', 'short_name': 'Delegación Santa María Totoltepec', 'types': ['sublocality_level_1', 'sublocality', 'political']}, {'long_name': 'Estado de México', 'short_name': 'Méx.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}, {'long_name': '50240', 'short_name': '50240', 'types': ['postal_code']}]
